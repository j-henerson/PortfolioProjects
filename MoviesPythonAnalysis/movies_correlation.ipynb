# %%
# Import Libraries
import numpy as np
import pandas as pd
import seaborn as sns

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline 
matplotlib.rcParams['figure.figsize'] = (12,8) # Adjusts configuration of plots

# Read in the data

df = pd.read_csv(r'C:\Users\Jeremy Henerson\OneDrive\Desktop\data analysis portfolio\movies.csv')

# %%
# Looking at the data

df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000.0
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000.0
# 2           Leigh Brackett     Mark Hamill   United States  18000000.0
# 3             Jim Abrahams     Robert Hays   United States   3500000.0
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000.0
#
#          gross             company  runtime
# 0   46998772.0        Warner Bros.    146.0
# 1   58853106.0   Columbia Pictures    104.0
# 2  538375067.0           Lucasfilm    124.0
# 3   83453539.0  Paramount Pictures     88.0
# 4   39846344.0      Orion Pictures     98.0

# %%
# Looking for missing data

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# name - 0.0%
# rating - 0.002207505518763797%
# genre - 0.0%
# year - 0.0%
# released - 0.0%
# score - 0.0%
# votes - 0.0%
# director - 0.0%
# writer - 0.0%
# star - 0.0%
# country - 0.0001839587932303164%
# budget - 0.0%
# gross - 0.0%
# company - 0.0003679175864606328%
# runtime - 0.0001839587932303164%

# %%
# Removing rows with NaN for Budget and Gross

df = df[df['budget'].notnull()]
df = df[df['gross'].notnull()]

# %%
# Column data types

df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# Change column data types 

df['budget'] = df['budget'].astype('int64')

df['gross'] = df['gross'].astype('int64')

# %%
# Creating a function to get the correct year from the release date, as the year released column does not always match

def getyear(date):
        return date[(date.find(',')+2):(date.find(',')+7)]
df['revised_year'] = df['released'].apply(getyear)

# %%
df = df.sort_values(by='gross', inplace=False, ascending=False)

# %%
# View entire dataframe
pd.set_option('display.max_rows' , None)

# %%
# Drop any duplicates

df.drop_duplicates().head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country     budget  \
# 5445       James Cameron    Sam Worthington  United States  237000000
# 7445  Christopher Markus  Robert Downey Jr.  United States  356000000
# 3045       James Cameron  Leonardo DiCaprio  United States  200000000
# 6663     Lawrence Kasdan       Daisy Ridley  United States  245000000
# 7244  Christopher Markus  Robert Downey Jr.  United States  321000000
#
#            gross                company  runtime revised_year
# 5445  2847246203  Twentieth Century Fox    162.0        2009
# 7445  2797501328         Marvel Studios    181.0        2019
# 3045  2201647264  Twentieth Century Fox    194.0        1997
# 6663  2069521700              Lucasfilm    138.0        2015
# 7244  2048359754         Marvel Studios    149.0        2018

# %%
# Scatter Plot with Budget vs. Gross 

plt.scatter(x=df['budget'],y=df['gross'])
plt.title('Budget vs. Gross Earnings')
plt.xlabel('Budget')
plt.ylabel('Gross Earnings')
plt.show()

# %%
# Plot the budget vs gross using Seaborn

sns.regplot(x='budget', y='gross', data=df, scatter_kws={'color':'red'}, line_kws={'color':'blue'})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
# Observing correlation

df.corr(method='pearson')
# There is a high correlation between budget and gross
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.055174  0.205758  0.327781  0.274264  0.074203
# score    0.055174  1.000000  0.473809  0.071792  0.222143  0.414580
# votes    0.205758  0.473809  1.000000  0.440021  0.614904  0.352437
# budget   0.327781  0.071792  0.440021  1.000000  0.740395  0.318595
# gross    0.274264  0.222143  0.614904  0.740395  1.000000  0.275596
# runtime  0.074203  0.414580  0.352437  0.318595  0.275596  1.000000

# %%
correlation_matrix = df.corr(method='pearson')
# Heatmap of numeric correlations in dataset
sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation Matrix for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
# Looking at company
df_numeric = df

for col_name in df_numeric.columns:
    if(df_numeric[col_name].dtype == 'object'):
        df_numeric[col_name] = df_numeric[col_name].astype('category')
        df_numeric[col_name] = df_numeric[col_name].cat.codes

df_numeric.head()
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 5445   387       5      0  2009       528    7.8  1100000.0       787    1265
# 7445   389       5      0  2019       138    8.4   903000.0       106     515
# 3045  4923       5      6  1997       535    7.8  1100000.0       787    1265
# 6663  3656       5      0  2015       530    7.8   876000.0       770    1810
# 7244   390       5      0  2018       146    8.4   897000.0       106     515
#
#       star  country     budget       gross  company  runtime  revised_year
# 5445  1538       47  237000000  2847246203     1388    162.0            30
# 7445  1474       47  356000000  2797501328      987    181.0            40
# 3045  1076       47  200000000  2201647264     1388    194.0            18
# 6663   357       47  245000000  2069521700      949    138.0            36
# 7244  1474       47  321000000  2048359754      987    149.0            39

# %%
num_correlation_matrix = df_numeric.corr(method='pearson')
# Heatmap of all correlations in dataset
sns.heatmap(num_correlation_matrix, annot=True)
plt.title('Correlation Matrix for All Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
num_correlation_matrix

corr_pairs = num_correlation_matrix.unstack()
corr_pairs
# Out:
# name          name            1.000000
#               rating         -0.023013
#               genre           0.009617
#               year            0.024435
#               released       -0.005896
#               score           0.014955
#               votes           0.012915
#               director        0.013699
#               writer          0.011602
#               star           -0.007109
#               country        -0.024555
#               budget          0.023698
#               gross           0.005966
#               company         0.021209
#               runtime         0.010800
#               revised_year    0.023698
# rating        name           -0.023013
#               rating          1.000000
#               genre           0.128102
#               year            0.022668
#               released        0.018836
#               score           0.059550
#               votes           0.009255
#               director        0.014847
#               writer         -0.006923
#               star            0.003737
#               country         0.020148
#               budget         -0.186892
#               gross          -0.168814
#               company        -0.082189
#               runtime         0.133239
#               revised_year    0.025578
# genre         name            0.009617
#               rating          0.128102
#               genre           1.000000
#               year           -0.073026
#               released        0.021712
#               score           0.034061
#               votes          -0.136457
#               director       -0.009303
#               writer          0.017500
#               star            0.002619
#               country        -0.010847
#               budget         -0.368900
#               gross          -0.244380
#               company        -0.073293
#               runtime        -0.060186
#               revised_year   -0.059733
# year          name            0.024435
#               rating          0.022668
#               genre          -0.073026
#               year            1.000000
#               released       -0.001481
#               score           0.055174
#               votes           0.205758
#               director       -0.036936
#               writer         -0.024568
#               star           -0.032770
#               country        -0.066662
#               budget          0.327781
#               gross           0.274264
#               company        -0.013062
#               runtime         0.074203
#               revised_year    0.984099
# released      name           -0.005896
#               rating          0.018836
#               genre           0.021712
#               year           -0.001481
#               released        1.000000
#               score           0.046424
#               votes           0.029029
#               director        0.003341
#               writer          0.008514
#               star            0.015363
#               country        -0.017231
#               budget          0.019888
#               gross           0.008614
#               company        -0.002927
#               runtime         0.008619
#               revised_year   -0.006572
# score         name            0.014955
#               rating          0.059550
#               genre           0.034061
#               year            0.055174
#               released        0.046424
#               score           1.000000
#               votes           0.473809
#               director        0.005573
#               writer          0.012860
#               star            0.009121
#               country        -0.044690
#               budget          0.071792
#               gross           0.222143
#               company         0.021054
#               runtime         0.414580
#               revised_year    0.058789
# votes         name            0.012915
#               rating          0.009255
#               genre          -0.136457
#               year            0.205758
#               released        0.029029
#               score           0.473809
#               votes           1.000000
#               director       -0.010198
#               writer         -0.005394
#               star           -0.017140
#               country         0.042146
#               budget          0.440021
#               gross           0.614904
#               company         0.119366
#               runtime         0.352437
#               revised_year    0.197578
# director      name            0.013699
#               rating          0.014847
#               genre          -0.009303
#               year           -0.036936
#               released        0.003341
#               score           0.005573
#               votes          -0.010198
#               director        1.000000
#               writer          0.262940
#               star            0.036289
#               country         0.011108
#               budget         -0.009340
#               gross          -0.029366
#               company        -0.007337
#               runtime         0.018082
#               revised_year   -0.034233
# writer        name            0.011602
#               rating         -0.006923
#               genre           0.017500
#               year           -0.024568
#               released        0.008514
#               score           0.012860
#               votes          -0.005394
#               director        0.262940
#               writer          1.000000
#               star            0.019273
#               country         0.022153
#               budget         -0.039420
#               gross          -0.035999
#               company        -0.002658
#               runtime        -0.016672
#               revised_year   -0.022282
# star          name           -0.007109
#               rating          0.003737
#               genre           0.002619
#               year           -0.032770
#               released        0.015363
#               score           0.009121
#               votes          -0.017140
#               director        0.036289
#               writer          0.019273
#               star            1.000000
#               country        -0.010135
#               budget         -0.021282
#               gross          -0.000009
#               company         0.015086
#               runtime         0.012439
#               revised_year   -0.034988
# country       name           -0.024555
#               rating          0.020148
#               genre          -0.010847
#               year           -0.066662
#               released       -0.017231
#               score          -0.044690
#               votes           0.042146
#               director        0.011108
#               writer          0.022153
#               star           -0.010135
#               country         1.000000
#               budget          0.054372
#               gross           0.060929
#               company         0.049559
#               runtime        -0.033554
#               revised_year   -0.075073
# budget        name            0.023698
#               rating         -0.186892
#               genre          -0.368900
#               year            0.327781
#               released        0.019888
#               score           0.071792
#               votes           0.440021
#               director       -0.009340
#               writer         -0.039420
#               star           -0.021282
#               country         0.054372
#               budget          1.000000
#               gross           0.740395
#               company         0.171385
#               runtime         0.318595
#               revised_year    0.313546
# gross         name            0.005966
#               rating         -0.168814
#               genre          -0.244380
#               year            0.274264
#               released        0.008614
#               score           0.222143
#               votes           0.614904
#               director       -0.029366
#               writer         -0.035999
#               star           -0.000009
#               country         0.060929
#               budget          0.740395
#               gross           1.000000
#               company         0.150233
#               runtime         0.275596
#               revised_year    0.263373
# company       name            0.021209
#               rating         -0.082189
#               genre          -0.073293
#               year           -0.013062
#               released       -0.002927
#               score           0.021054
#               votes           0.119366
#               director       -0.007337
#               writer         -0.002658
#               star            0.015086
#               country         0.049559
#               budget          0.171385
#               gross           0.150233
#               company         1.000000
#               runtime         0.038752
#               revised_year   -0.021090
# runtime       name            0.010800
#               rating          0.133239
#               genre          -0.060186
#               year            0.074203
#               released        0.008619
#               score           0.414580
#               votes           0.352437
#               director        0.018082
#               writer         -0.016672
#               star            0.012439
#               country        -0.033554
#               budget          0.318595
#               gross           0.275596
#               company         0.038752
#               runtime         1.000000
#               revised_year    0.071826
# revised_year  name            0.023698
#               rating          0.025578
#               genre          -0.059733
#               year            0.984099
#               released       -0.006572
#               score           0.058789
#               votes           0.197578
#               director       -0.034233
#               writer         -0.022282
#               star           -0.034988
#               country        -0.075073
#               budget          0.313546
#               gross           0.263373
#               company        -0.021090
#               runtime         0.071826
#               revised_year    1.000000
# dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values()

sorted_pairs
# Out:
# genre         budget         -0.368900
# budget        genre          -0.368900
# genre         gross          -0.244380
# gross         genre          -0.244380
# rating        budget         -0.186892
# budget        rating         -0.186892
# rating        gross          -0.168814
# gross         rating         -0.168814
# votes         genre          -0.136457
# genre         votes          -0.136457
# company       rating         -0.082189
# rating        company        -0.082189
# country       revised_year   -0.075073
# revised_year  country        -0.075073
# company       genre          -0.073293
# genre         company        -0.073293
# year          genre          -0.073026
# genre         year           -0.073026
# year          country        -0.066662
# country       year           -0.066662
# genre         runtime        -0.060186
# runtime       genre          -0.060186
# revised_year  genre          -0.059733
# genre         revised_year   -0.059733
# score         country        -0.044690
# country       score          -0.044690
# budget        writer         -0.039420
# writer        budget         -0.039420
# director      year           -0.036936
# year          director       -0.036936
# writer        gross          -0.035999
# gross         writer         -0.035999
# revised_year  star           -0.034988
# star          revised_year   -0.034988
# director      revised_year   -0.034233
# revised_year  director       -0.034233
# runtime       country        -0.033554
# country       runtime        -0.033554
# year          star           -0.032770
# star          year           -0.032770
# gross         director       -0.029366
# director      gross          -0.029366
# writer        year           -0.024568
# year          writer         -0.024568
# country       name           -0.024555
# name          country        -0.024555
#               rating         -0.023013
# rating        name           -0.023013
# revised_year  writer         -0.022282
# writer        revised_year   -0.022282
# star          budget         -0.021282
# budget        star           -0.021282
# revised_year  company        -0.021090
# company       revised_year   -0.021090
# country       released       -0.017231
# released      country        -0.017231
# star          votes          -0.017140
# votes         star           -0.017140
# writer        runtime        -0.016672
# runtime       writer         -0.016672
# year          company        -0.013062
# company       year           -0.013062
# genre         country        -0.010847
# country       genre          -0.010847
# director      votes          -0.010198
# votes         director       -0.010198
# country       star           -0.010135
# star          country        -0.010135
# budget        director       -0.009340
# director      budget         -0.009340
#               genre          -0.009303
# genre         director       -0.009303
# director      company        -0.007337
# company       director       -0.007337
# name          star           -0.007109
# star          name           -0.007109
# rating        writer         -0.006923
# writer        rating         -0.006923
# released      revised_year   -0.006572
# revised_year  released       -0.006572
# released      name           -0.005896
# name          released       -0.005896
# votes         writer         -0.005394
# writer        votes          -0.005394
# released      company        -0.002927
# company       released       -0.002927
#               writer         -0.002658
# writer        company        -0.002658
# released      year           -0.001481
# year          released       -0.001481
# gross         star           -0.000009
# star          gross          -0.000009
#               genre           0.002619
# genre         star            0.002619
# released      director        0.003341
# director      released        0.003341
# rating        star            0.003737
# star          rating          0.003737
# director      score           0.005573
# score         director        0.005573
# gross         name            0.005966
# name          gross           0.005966
# writer        released        0.008514
# released      writer          0.008514
# gross         released        0.008614
# released      gross           0.008614
#               runtime         0.008619
# runtime       released        0.008619
# score         star            0.009121
# star          score           0.009121
# votes         rating          0.009255
# rating        votes           0.009255
# genre         name            0.009617
# name          genre           0.009617
#               runtime         0.010800
# runtime       name            0.010800
# director      country         0.011108
# country       director        0.011108
# writer        name            0.011602
# name          writer          0.011602
# runtime       star            0.012439
# star          runtime         0.012439
# score         writer          0.012860
# writer        score           0.012860
# name          votes           0.012915
# votes         name            0.012915
# director      name            0.013699
# name          director        0.013699
# rating        director        0.014847
# director      rating          0.014847
# score         name            0.014955
# name          score           0.014955
# company       star            0.015086
# star          company         0.015086
#               released        0.015363
# released      star            0.015363
# writer        genre           0.017500
# genre         writer          0.017500
# runtime       director        0.018082
# director      runtime         0.018082
# released      rating          0.018836
# rating        released        0.018836
# writer        star            0.019273
# star          writer          0.019273
# budget        released        0.019888
# released      budget          0.019888
# rating        country         0.020148
# country       rating          0.020148
# company       score           0.021054
# score         company         0.021054
# name          company         0.021209
# company       name            0.021209
# genre         released        0.021712
# released      genre           0.021712
# country       writer          0.022153
# writer        country         0.022153
# rating        year            0.022668
# year          rating          0.022668
# budget        name            0.023698
# name          budget          0.023698
# revised_year  name            0.023698
# name          revised_year    0.023698
#               year            0.024435
# year          name            0.024435
# rating        revised_year    0.025578
# revised_year  rating          0.025578
# released      votes           0.029029
# votes         released        0.029029
# genre         score           0.034061
# score         genre           0.034061
# director      star            0.036289
# star          director        0.036289
# runtime       company         0.038752
# company       runtime         0.038752
# country       votes           0.042146
# votes         country         0.042146
# score         released        0.046424
# released      score           0.046424
# country       company         0.049559
# company       country         0.049559
# country       budget          0.054372
# budget        country         0.054372
# score         year            0.055174
# year          score           0.055174
# revised_year  score           0.058789
# score         revised_year    0.058789
#               rating          0.059550
# rating        score           0.059550
# country       gross           0.060929
# gross         country         0.060929
# budget        score           0.071792
# score         budget          0.071792
# runtime       revised_year    0.071826
# revised_year  runtime         0.071826
# runtime       year            0.074203
# year          runtime         0.074203
# company       votes           0.119366
# votes         company         0.119366
# rating        genre           0.128102
# genre         rating          0.128102
# rating        runtime         0.133239
# runtime       rating          0.133239
# company       gross           0.150233
# gross         company         0.150233
# company       budget          0.171385
# budget        company         0.171385
# revised_year  votes           0.197578
# votes         revised_year    0.197578
# year          votes           0.205758
# votes         year            0.205758
# score         gross           0.222143
# gross         score           0.222143
# director      writer          0.262940
# writer        director        0.262940
# gross         revised_year    0.263373
# revised_year  gross           0.263373
# year          gross           0.274264
# gross         year            0.274264
#               runtime         0.275596
# runtime       gross           0.275596
# budget        revised_year    0.313546
# revised_year  budget          0.313546
# budget        runtime         0.318595
# runtime       budget          0.318595
# budget        year            0.327781
# year          budget          0.327781
# runtime       votes           0.352437
# votes         runtime         0.352437
# score         runtime         0.414580
# runtime       score           0.414580
# budget        votes           0.440021
# votes         budget          0.440021
# score         votes           0.473809
# votes         score           0.473809
# gross         votes           0.614904
# votes         gross           0.614904
# budget        gross           0.740395
# gross         budget          0.740395
# revised_year  year            0.984099
# year          revised_year    0.984099
# name          name            1.000000
# company       company         1.000000
# gross         gross           1.000000
# budget        budget          1.000000
# country       country         1.000000
# star          star            1.000000
# writer        writer          1.000000
# director      director        1.000000
# votes         votes           1.000000
# score         score           1.000000
# released      released        1.000000
# year          year            1.000000
# genre         genre           1.000000
# rating        rating          1.000000
# runtime       runtime         1.000000
# revised_year  revised_year    1.000000
# dtype: float64

# %%
high_corr = sorted_pairs[sorted_pairs > .5]

high_corr
# Out:
# gross         votes           0.614904
# votes         gross           0.614904
# budget        gross           0.740395
# gross         budget          0.740395
# revised_year  year            0.984099
# year          revised_year    0.984099
# name          name            1.000000
# company       company         1.000000
# gross         gross           1.000000
# budget        budget          1.000000
# country       country         1.000000
# star          star            1.000000
# writer        writer          1.000000
# director      director        1.000000
# votes         votes           1.000000
# score         score           1.000000
# released      released        1.000000
# year          year            1.000000
# genre         genre           1.000000
# rating        rating          1.000000
# runtime       runtime         1.000000
# revised_year  revised_year    1.000000
# dtype: float64

# %%
# Votes and budget have the highest correlation to gross earnings
# Company has low correlation
